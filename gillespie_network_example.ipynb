# %%
import numpy as np
from models.sim_all_network import Fires_Simulation_Network
import time
import matplotlib.pyplot as plt
import networkx as nx

# %%
# death, birth, propagation
N = 250
dF, bF, lF = 1, 0.5, 10
dV, bV, lV = 0.01, 0, 0.4

model = Fires_Simulation_Network(N, nx.complete_graph(N), [dF, bF, lF], [dV, bV, lV])

# %%
tmax = 10
model.Gillespie(int(1e6), tmax)
# Out:
# Step: 0, real time: 0

# %%
fig, ax = model.plot_probabilities(save = False)
plt.show()
